# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\lenov\\OneDrive\\Documents\\projects\\Kidney-disease-classification-Deep-learning-project\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\lenov\\OneDrive\\Documents\\projects\\Kidney-disease-classification-Deep-learning-project'

# %%
from dataclasses import dataclass

from pathlib import Path





@dataclass(frozen=True)

class TrainingConfig:

    root_dir: Path

    trained_model_path: Path

    updated_base_model_path: Path

    training_data: Path

    params_epochs: int

    params_batch_size: int

    params_is_augmentation: bool

    params_image_size: list

    params_learning_rate: float

# %%
from cnnClassifier.constants import *

from cnnClassifier.utils.common import read_yaml, create_directories

import tensorflow as tf

# %%
class ConfigurationManager:

    def __init__(

        self,

        config_filepath = CONFIG_FILE_PATH,

        params_filepath = PARAMS_FILE_PATH):



        self.config = read_yaml(config_filepath)

        self.params = read_yaml(params_filepath)



        create_directories([self.config.artifacts_root])





    

    def get_training_config(self) -> TrainingConfig:

        training = self.config.training

        prepare_base_model = self.config.prepare_base_model

        params = self.params

        training_data = os.path.join(self.config.data_ingestion.unzip_dir, "kidney-ct-scan-image")

        create_directories([

            Path(training.root_dir)

        ])



        training_config = TrainingConfig(

            root_dir=Path(training.root_dir),

            trained_model_path=Path(training.trained_model_path),

            updated_base_model_path=Path(prepare_base_model.updated_base_model_path),

            training_data=Path(training_data),

            params_epochs=params.EPOCHS,

            params_batch_size=params.BATCH_SIZE,

            params_is_augmentation=params.AUGMENTATION,

            params_image_size=params.IMAGE_SIZE,

            params_learning_rate=params.LEARNING_RATE

        )



        return training_config

# %%
import os

import urllib.request as request

from zipfile import ZipFile

import tensorflow as tf

import time

from xml.parsers.expat import model

# %%
class Training:

    def __init__(self, config: TrainingConfig):

        self.config = config



    

    def get_base_model(self):

        self.model = tf.keras.models.load_model(self.config.updated_base_model_path)
    
        # Cosine decay learning rate schedule for smoother convergence
        lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
            initial_learning_rate=1e-4,
            decay_steps=10000,
            alpha=1e-6
        )
        self.model.compile(

            optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),

            loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),

            metrics=["accuracy", tf.keras.metrics.Precision(), tf.keras.metrics.Recall(),tf.keras.metrics.AUC()]

        )



    def train_valid_generator(self):



        datagenerator_kwargs = dict(

            rescale = 1./255,

            validation_split=0.20

        )



        dataflow_kwargs = dict(

            target_size=self.config.params_image_size[:-1],

            batch_size=self.config.params_batch_size,

            interpolation="bilinear"

        )



        valid_datagenerator = tf.keras.preprocessing.image.ImageDataGenerator(

            **datagenerator_kwargs

        )



        self.valid_generator = valid_datagenerator.flow_from_directory(

            directory=self.config.training_data,

            subset="validation",

            shuffle=False,
            class_mode="categorical",

            **dataflow_kwargs

        )



        if self.config.params_is_augmentation:

            train_datagenerator = tf.keras.preprocessing.image.ImageDataGenerator(

                rotation_range=20,

                horizontal_flip=True,

                width_shift_range=0.2,

                height_shift_range=0.2,

                brightness_range=[0.8, 1.2],

                shear_range=0.2,

                zoom_range=0.2,

                **datagenerator_kwargs

            )

        else:

            train_datagenerator = valid_datagenerator



        self.train_generator = train_datagenerator.flow_from_directory(

            directory=self.config.training_data,

            subset="training",

            shuffle=True,

            **dataflow_kwargs

        )



    

    @staticmethod

    def save_model(path: Path, model: tf.keras.Model):

        model.save(path)



    

    def train(self):

        self.steps_per_epoch = self.train_generator.samples // self.train_generator.batch_size

        self.validation_steps = self.valid_generator.samples // self.valid_generator.batch_size
    


    



        self.model.fit(
            self.train_generator,
            epochs=self.config.params_epochs,
            steps_per_epoch=self.steps_per_epoch,
            validation_steps=self.validation_steps,
            validation_data=self.valid_generator,
            callbacks=[
                tf.keras.callbacks.EarlyStopping(
                    monitor="val_loss",
                    patience=10,
                    restore_best_weights=True
                ),
                tf.keras.callbacks.ModelCheckpoint(
                    filepath=self.config.trained_model_path,
                    monitor="val_loss",
                    save_best_only=True,
                ),
                # tf.keras.callbacks.ReduceLROnPlateau(
                #     monitor="val_loss",
                #     factor=0.2,
                #     patience=3,
                #     min_lr=1e-7

                # )
            ]
        )



        self.save_model(

            path=self.config.trained_model_path,

            model=self.model

        )

# %%
try:

    config = ConfigurationManager()

    training_config = config.get_training_config()

    training = Training(config=training_config)

    training.get_base_model()

    training.train_valid_generator()

    training.train()

    

except Exception as e:

    raise e
# Out:
# [2026-05-25 13:48:32,674:INFO:common:yaml file: config\config.yaml loaded successfully]
# [2026-05-25 13:48:32,678:INFO:common:yaml file: params.yaml loaded successfully]
# [2026-05-25 13:48:32,680:INFO:common:created directory at: artifacts]
# [2026-05-25 13:48:32,681:INFO:common:created directory at: artifacts\training]
# Found 400 images belonging to 4 classes.
# Found 1600 images belonging to 4 classes.
# Epoch 1/25
# 50/50 [==============================] - 33s 360ms/step - loss: 1.1562 - accuracy: 0.6263 - precision: 0.6978 - recall: 0.5269 - auc: 0.8485 - val_loss: 1.4200 - val_accuracy: 0.4792 - val_precision: 0.5000 - val_recall: 0.0286 - val_auc: 0.6621
# Epoch 2/25
# 50/50 [==============================] - 18s 346ms/step - loss: 0.6654 - accuracy: 0.8931 - precision: 0.9287 - recall: 0.8544 - auc: 0.9855 - val_loss: 1.2922 - val_accuracy: 0.6406 - val_precision: 1.0000 - val_recall: 0.0104 - val_auc: 0.7422
# Epoch 3/25
# 50/50 [==============================] - 17s 339ms/step - loss: 0.5460 - accuracy: 0.9700 - precision: 0.9781 - recall: 0.9500 - auc: 0.9967 - val_loss: 1.3084 - val_accuracy: 0.4635 - val_precision: 0.1765 - val_recall: 0.0078 - val_auc: 0.7209
# Epoch 4/25
# 50/50 [==============================] - 18s 348ms/step - loss: 0.4906 - accuracy: 0.9844 - precision: 0.9929 - recall: 0.9675 - auc: 0.9994 - val_loss: 1.2891 - val_accuracy: 0.5156 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7506
# Epoch 5/25
# 50/50 [==============================] - 17s 341ms/step - loss: 0.4603 - accuracy: 0.9944 - precision: 0.9975 - recall: 0.9912 - auc: 0.9999 - val_loss: 1.3045 - val_accuracy: 0.4349 - val_precision: 1.0000 - val_recall: 0.0156 - val_auc: 0.7125
# Epoch 6/25
# 50/50 [==============================] - 17s 345ms/step - loss: 0.4416 - accuracy: 0.9981 - precision: 0.9994 - recall: 0.9950 - auc: 1.0000 - val_loss: 1.2206 - val_accuracy: 0.5964 - val_precision: 1.0000 - val_recall: 0.0156 - val_auc: 0.8245
# Epoch 7/25
# 50/50 [==============================] - 17s 343ms/step - loss: 0.4382 - accuracy: 0.9987 - precision: 0.9987 - recall: 0.9981 - auc: 1.0000 - val_loss: 1.2072 - val_accuracy: 0.4792 - val_precision: 0.9118 - val_recall: 0.0807 - val_auc: 0.7986
# Epoch 8/25
# 50/50 [==============================] - 18s 351ms/step - loss: 0.4330 - accuracy: 0.9981 - precision: 0.9987 - recall: 0.9962 - auc: 1.0000 - val_loss: 1.1298 - val_accuracy: 0.6849 - val_precision: 0.9375 - val_recall: 0.1562 - val_auc: 0.8616
# Epoch 9/25
# 50/50 [==============================] - 18s 346ms/step - loss: 0.4249 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9987 - auc: 1.0000 - val_loss: 1.0573 - val_accuracy: 0.6979 - val_precision: 0.9133 - val_recall: 0.3568 - val_auc: 0.8928
# Epoch 10/25
# 50/50 [==============================] - 18s 347ms/step - loss: 0.4270 - accuracy: 0.9987 - precision: 0.9994 - recall: 0.9975 - auc: 1.0000 - val_loss: 1.0082 - val_accuracy: 0.6693 - val_precision: 0.8315 - val_recall: 0.3854 - val_auc: 0.8949
# Epoch 11/25
# 50/50 [==============================] - 17s 340ms/step - loss: 0.4213 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9994 - auc: 1.0000 - val_loss: 1.0387 - val_accuracy: 0.7083 - val_precision: 0.8000 - val_recall: 0.4896 - val_auc: 0.8614
# Epoch 12/25
# 50/50 [==============================] - 18s 349ms/step - loss: 0.4174 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 1.0073 - val_accuracy: 0.6406 - val_precision: 0.7791 - val_recall: 0.5052 - val_auc: 0.8750
# Epoch 13/25
# 50/50 [==============================] - 17s 343ms/step - loss: 0.4134 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 1.0084 - val_accuracy: 0.6745 - val_precision: 0.7580 - val_recall: 0.5547 - val_auc: 0.8685
# Epoch 14/25
# 50/50 [==============================] - 17s 340ms/step - loss: 0.4108 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9994 - auc: 1.0000 - val_loss: 1.0241 - val_accuracy: 0.6536 - val_precision: 0.7313 - val_recall: 0.5599 - val_auc: 0.8682
# Epoch 15/25
# 50/50 [==============================] - 17s 344ms/step - loss: 0.4111 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.9893 - val_accuracy: 0.6719 - val_precision: 0.7524 - val_recall: 0.6172 - val_auc: 0.8881
# Epoch 16/25
# 50/50 [==============================] - 17s 344ms/step - loss: 0.4096 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.9425 - val_accuracy: 0.7057 - val_precision: 0.8514 - val_recall: 0.6120 - val_auc: 0.8965
# Epoch 17/25
# 50/50 [==============================] - 17s 337ms/step - loss: 0.4082 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.9571 - val_accuracy: 0.7318 - val_precision: 0.7612 - val_recall: 0.6641 - val_auc: 0.9030
# Epoch 18/25
# 50/50 [==============================] - 17s 343ms/step - loss: 0.4089 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9994 - auc: 1.0000 - val_loss: 0.8389 - val_accuracy: 0.7292 - val_precision: 0.7635 - val_recall: 0.5885 - val_auc: 0.9323
# Epoch 19/25
# 50/50 [==============================] - 17s 339ms/step - loss: 0.4094 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 1.2079 - val_accuracy: 0.6354 - val_precision: 0.6657 - val_recall: 0.6172 - val_auc: 0.8504
# Epoch 20/25
# 50/50 [==============================] - 17s 343ms/step - loss: 0.4063 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9994 - auc: 1.0000 - val_loss: 0.8350 - val_accuracy: 0.7552 - val_precision: 0.7720 - val_recall: 0.6615 - val_auc: 0.9392
# Epoch 21/25
# 50/50 [==============================] - 18s 345ms/step - loss: 0.4036 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 1.0369 - val_accuracy: 0.6901 - val_precision: 0.7601 - val_recall: 0.6354 - val_auc: 0.8813
# Epoch 22/25
# 50/50 [==============================] - 17s 342ms/step - loss: 0.4071 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9994 - auc: 1.0000 - val_loss: 1.0597 - val_accuracy: 0.6823 - val_precision: 0.7346 - val_recall: 0.5911 - val_auc: 0.8773
# Epoch 23/25
# 50/50 [==============================] - 17s 341ms/step - loss: 0.4085 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9994 - auc: 1.0000 - val_loss: 1.1384 - val_accuracy: 0.6849 - val_precision: 0.7126 - val_recall: 0.6458 - val_auc: 0.8642
# Epoch 24/25
# 50/50 [==============================] - 17s 338ms/step - loss: 0.4028 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 1.1190 - val_accuracy: 0.6562 - val_precision: 0.6893 - val_recall: 0.6068 - val_auc: 0.8606
# Epoch 25/25
# 50/50 [==============================] - 17s 339ms/step - loss: 0.4024 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.9102 - val_accuracy: 0.7526 - val_precision: 0.7810 - val_recall: 0.7057 - val_auc: 0.9180
